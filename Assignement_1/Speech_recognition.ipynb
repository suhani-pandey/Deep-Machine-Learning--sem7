# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Loading and Exploring data

# %%
# load data
import numpy as np
x_data = np.load("/content/drive/My Drive/x_digits.npy")
y_data=np.load("/content/drive/My Drive/y_digits.npy")

# %%
# Data Exploration
print("X shape: ", x_data.shape)
print("Y shape: ", y_data.shape)
# Out:
# X shape:  (35631, 129, 71)
# Y shape:  (35631,)

# %%
import matplotlib.pyplot as plt

plt.imshow(x_data[0], cmap='inferno')
plt.title(f"Spectrogram of Digit {y_data[0]}")
plt.colorbar()
plt.show()

# %%
# to see how many times each number appears in the dataset to have certain understanding
import numpy as np

unique, counts = np.unique(y_data, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0.0: 3757, 1.0: 3492, 2.0: 3525, 3.0: 3403, 4.0: 3403, 5.0: 3727, 6.0: 3598, 7.0: 3668, 8.0: 3429, 9.0: 3629}

# %%
# split the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, stratify= y_data)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify= y_train)
x_train,x_val,x_test=X_train/255.,X_val/255.,X_test/255.

print("X_train shape: ", X_train.shape)
print("X_val shape: ", X_val.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (20042, 129, 71)
# X_val shape:  (6681, 129, 71)
# X_test shape:  (8908, 129, 71)

# %% [markdown]
# # FCNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout,LeakyReLU, BatchNormalization
from tensorflow.keras.optimizers import AdamW, RMSprop, SGD,Adam
from tensorflow.keras.callbacks import LearningRateScheduler

# Function to build FCNN model
def build_fcnn(optimizer, dropout_rate=0.2):
    model = Sequential([
        tf.keras.layers.Input(shape=(129, 71)),
        Flatten(),
        Dense(124, activation='swish', kernel_initializer="he_normal"),
        BatchNormalization(),
        Dropout(dropout_rate),
        Dense(124, activation='swish', kernel_initializer="he_normal"),
        BatchNormalization(),
        Dropout(dropout_rate),
        Dense(124, activation='swish', kernel_initializer="he_normal"),
        BatchNormalization(),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Define optimizers
optimizers = {
    'Adam': Adam(learning_rate=0.0005),
    'RMSprop': RMSprop(learning_rate=0.0005),
    'NAG': SGD(learning_rate=0.0005, momentum=0.75, nesterov=True)
}

# %%
# Train models and store histories
histories = {}
for opt_name, opt in optimizers.items():
    print(f'Training with {opt_name}...')
    model = build_fcnn(opt)
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=1)
    histories[opt_name] = history
# Out:
# Training with Adam...
# Epoch 1/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3007 - loss: 2.0789 - val_accuracy: 0.5897 - val_loss: 1.2665
# Epoch 2/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5407 - loss: 1.3313 - val_accuracy: 0.6319 - val_loss: 1.0438
# Epoch 3/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6155 - loss: 1.1101 - val_accuracy: 0.7234 - val_loss: 0.8328
# Epoch 4/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6603 - loss: 0.9809 - val_accuracy: 0.7203 - val_loss: 0.8229
# Epoch 5/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6888 - loss: 0.8976 - val_accuracy: 0.7479 - val_loss: 0.7486
# Epoch 6/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7127 - loss: 0.8449 - val_accuracy: 0.7777 - val_loss: 0.6751
# Epoch 7/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7376 - loss: 0.7717 - val_accuracy: 0.7446 - val_loss: 0.7342
# Epoch 8/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7330 - loss: 0.7688 - val_accuracy: 0.7894 - val_loss: 0.6187
# Epoch 9/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7565 - loss: 0.7173 - val_accuracy: 0.7954 - val_loss: 0.6162
# Epoch 10/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7734 - loss: 0.6680 - val_accuracy: 0.8048 - val_loss: 0.5883
# Epoch 11/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7832 - loss: 0.6356 - val_accuracy: 0.8126 - val_loss: 0.5484
# Epoch 12/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7929 - loss: 0.6011 - val_accuracy: 0.8163 - val_loss: 0.5457
# Epoch 13/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8013 - loss: 0.5784 - val_accuracy: 0.8083 - val_loss: 0.5552
# Epoch 14/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8159 - loss: 0.5454 - val_accuracy: 0.8107 - val_loss: 0.5673
# Epoch 15/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8132 - loss: 0.5526 - val_accuracy: 0.8041 - val_loss: 0.5816
# Epoch 16/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8169 - loss: 0.5348 - val_accuracy: 0.8315 - val_loss: 0.5110
# Epoch 17/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8348 - loss: 0.4872 - val_accuracy: 0.7810 - val_loss: 0.6616
# Epoch 18/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8324 - loss: 0.4979 - val_accuracy: 0.8273 - val_loss: 0.5099
# Epoch 19/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8406 - loss: 0.4726 - val_accuracy: 0.8307 - val_loss: 0.5178
# Epoch 20/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8500 - loss: 0.4515 - val_accuracy: 0.8454 - val_loss: 0.4607
# Epoch 21/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.4522 - val_accuracy: 0.8090 - val_loss: 0.5969
# Epoch 22/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8561 - loss: 0.4191 - val_accuracy: 0.8461 - val_loss: 0.4744
# Epoch 23/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8589 - loss: 0.4146 - val_accuracy: 0.8277 - val_loss: 0.5260
# Epoch 24/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8628 - loss: 0.4091 - val_accuracy: 0.8388 - val_loss: 0.4929
# Epoch 25/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8612 - loss: 0.4113 - val_accuracy: 0.8434 - val_loss: 0.4836
# Epoch 26/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8704 - loss: 0.3825 - val_accuracy: 0.8433 - val_loss: 0.4895
# Epoch 27/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8646 - loss: 0.3942 - val_accuracy: 0.8135 - val_loss: 0.6085
# Epoch 28/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8713 - loss: 0.3861 - val_accuracy: 0.8385 - val_loss: 0.4885
# Epoch 29/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8694 - loss: 0.3808 - val_accuracy: 0.8392 - val_loss: 0.4980
# Epoch 30/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8717 - loss: 0.3712 - val_accuracy: 0.8369 - val_loss: 0.5072
# Epoch 31/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8815 - loss: 0.3521 - val_accuracy: 0.8279 - val_loss: 0.5493
# Epoch 32/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8844 - loss: 0.3430 - val_accuracy: 0.8535 - val_loss: 0.4740
# Epoch 33/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8863 - loss: 0.3328 - val_accuracy: 0.8565 - val_loss: 0.4431
# Epoch 34/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8973 - loss: 0.3068 - val_accuracy: 0.8374 - val_loss: 0.5006
# Epoch 35/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8967 - loss: 0.3116 - val_accuracy: 0.8409 - val_loss: 0.5076
# Epoch 36/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8998 - loss: 0.3045 - val_accuracy: 0.8289 - val_loss: 0.5497
# Epoch 37/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9067 - loss: 0.2799 - val_accuracy: 0.8520 - val_loss: 0.4934
# Epoch 38/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9081 - loss: 0.2755 - val_accuracy: 0.8298 - val_loss: 0.5512
# Epoch 39/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9074 - loss: 0.2809 - val_accuracy: 0.8541 - val_loss: 0.4759
# Epoch 40/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9116 - loss: 0.2677 - val_accuracy: 0.8475 - val_loss: 0.4813
# Epoch 41/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9029 - loss: 0.2876 - val_accuracy: 0.8407 - val_loss: 0.5332
# Epoch 42/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9081 - loss: 0.2696 - val_accuracy: 0.8578 - val_loss: 0.4530
# Epoch 43/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9108 - loss: 0.2603 - val_accuracy: 0.8324 - val_loss: 0.5738
# Epoch 44/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9084 - loss: 0.2657 - val_accuracy: 0.8445 - val_loss: 0.5090
# Epoch 45/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9099 - loss: 0.2637 - val_accuracy: 0.8602 - val_loss: 0.4508
# Epoch 46/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9070 - loss: 0.2680 - val_accuracy: 0.8571 - val_loss: 0.4704
# Epoch 47/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9169 - loss: 0.2481 - val_accuracy: 0.8153 - val_loss: 0.6351
# Epoch 48/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9186 - loss: 0.2382 - val_accuracy: 0.8623 - val_loss: 0.4481
# Epoch 49/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9194 - loss: 0.2365 - val_accuracy: 0.8505 - val_loss: 0.4931
# Epoch 50/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9126 - loss: 0.2605 - val_accuracy: 0.8593 - val_loss: 0.4524
# Training with RMSprop...
# Epoch 1/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.3030 - loss: 2.0719 - val_accuracy: 0.5453 - val_loss: 1.3342
# Epoch 2/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5443 - loss: 1.3178 - val_accuracy: 0.6854 - val_loss: 0.9696
# Epoch 3/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6391 - loss: 1.0527 - val_accuracy: 0.6551 - val_loss: 1.0203
# Epoch 4/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6686 - loss: 0.9491 - val_accuracy: 0.7292 - val_loss: 0.8064
# Epoch 5/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7033 - loss: 0.8550 - val_accuracy: 0.7243 - val_loss: 0.8069
# Epoch 6/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7300 - loss: 0.7911 - val_accuracy: 0.7373 - val_loss: 0.7744
# Epoch 7/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7529 - loss: 0.7398 - val_accuracy: 0.7250 - val_loss: 0.7954
# Epoch 8/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7629 - loss: 0.6983 - val_accuracy: 0.7484 - val_loss: 0.7560
# Epoch 9/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7755 - loss: 0.6569 - val_accuracy: 0.7925 - val_loss: 0.5972
# Epoch 10/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7899 - loss: 0.6198 - val_accuracy: 0.8134 - val_loss: 0.5575
# Epoch 11/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8051 - loss: 0.5798 - val_accuracy: 0.8210 - val_loss: 0.5514
# Epoch 12/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8103 - loss: 0.5614 - val_accuracy: 0.8175 - val_loss: 0.5418
# Epoch 13/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8200 - loss: 0.5305 - val_accuracy: 0.7816 - val_loss: 0.6609
# Epoch 14/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8309 - loss: 0.5062 - val_accuracy: 0.8184 - val_loss: 0.5546
# Epoch 15/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8364 - loss: 0.4837 - val_accuracy: 0.7891 - val_loss: 0.6258
# Epoch 16/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8392 - loss: 0.4790 - val_accuracy: 0.8301 - val_loss: 0.5244
# Epoch 17/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8440 - loss: 0.4593 - val_accuracy: 0.8297 - val_loss: 0.5359
# Epoch 18/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8492 - loss: 0.4491 - val_accuracy: 0.8337 - val_loss: 0.5109
# Epoch 19/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8611 - loss: 0.4105 - val_accuracy: 0.8357 - val_loss: 0.5053
# Epoch 20/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8642 - loss: 0.3988 - val_accuracy: 0.7966 - val_loss: 0.6306
# Epoch 21/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8647 - loss: 0.4019 - val_accuracy: 0.8264 - val_loss: 0.5335
# Epoch 22/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8712 - loss: 0.3816 - val_accuracy: 0.8339 - val_loss: 0.5147
# Epoch 23/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8792 - loss: 0.3618 - val_accuracy: 0.8339 - val_loss: 0.5218
# Epoch 24/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8743 - loss: 0.3646 - val_accuracy: 0.8407 - val_loss: 0.4799
# Epoch 25/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8852 - loss: 0.3423 - val_accuracy: 0.8301 - val_loss: 0.5531
# Epoch 26/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8778 - loss: 0.3563 - val_accuracy: 0.8222 - val_loss: 0.5588
# Epoch 27/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8883 - loss: 0.3279 - val_accuracy: 0.8313 - val_loss: 0.5551
# Epoch 28/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8956 - loss: 0.3192 - val_accuracy: 0.8434 - val_loss: 0.4903
# Epoch 29/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8951 - loss: 0.3068 - val_accuracy: 0.8280 - val_loss: 0.5383
# Epoch 30/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8959 - loss: 0.3139 - val_accuracy: 0.8307 - val_loss: 0.5216
# Epoch 31/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9014 - loss: 0.2944 - val_accuracy: 0.8256 - val_loss: 0.5416
# Epoch 32/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8978 - loss: 0.3013 - val_accuracy: 0.8367 - val_loss: 0.5315
# Epoch 33/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8996 - loss: 0.2993 - val_accuracy: 0.8481 - val_loss: 0.5077
# Epoch 34/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9054 - loss: 0.2819 - val_accuracy: 0.8421 - val_loss: 0.5209
# Epoch 35/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9060 - loss: 0.2833 - val_accuracy: 0.8277 - val_loss: 0.5770
# Epoch 36/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9098 - loss: 0.2664 - val_accuracy: 0.8454 - val_loss: 0.4943
# Epoch 37/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9084 - loss: 0.2711 - val_accuracy: 0.8403 - val_loss: 0.5268
# Epoch 38/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9135 - loss: 0.2594 - val_accuracy: 0.8285 - val_loss: 0.5769
# Epoch 39/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9156 - loss: 0.2565 - val_accuracy: 0.8615 - val_loss: 0.4588
# Epoch 40/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9192 - loss: 0.2430 - val_accuracy: 0.8258 - val_loss: 0.5878
# Epoch 41/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9136 - loss: 0.2553 - val_accuracy: 0.7780 - val_loss: 0.8011
# Epoch 42/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9172 - loss: 0.2422 - val_accuracy: 0.8442 - val_loss: 0.5591
# Epoch 43/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9194 - loss: 0.2429 - val_accuracy: 0.8343 - val_loss: 0.5844
# Epoch 44/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9226 - loss: 0.2344 - val_accuracy: 0.8348 - val_loss: 0.5614
# Epoch 45/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9266 - loss: 0.2201 - val_accuracy: 0.8409 - val_loss: 0.5477
# Epoch 46/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9252 - loss: 0.2229 - val_accuracy: 0.8280 - val_loss: 0.6112
# Epoch 47/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9262 - loss: 0.2289 - val_accuracy: 0.8241 - val_loss: 0.6356
# Epoch 48/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9266 - loss: 0.2150 - val_accuracy: 0.8443 - val_loss: 0.5319
# Epoch 49/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9337 - loss: 0.2039 - val_accuracy: 0.8419 - val_loss: 0.5662
# Epoch 50/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9312 - loss: 0.2064 - val_accuracy: 0.8394 - val_loss: 0.5857
# Training with NAG...
# Epoch 1/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.2392 - loss: 2.3000 - val_accuracy: 0.4730 - val_loss: 1.6120
# Epoch 2/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4178 - loss: 1.6972 - val_accuracy: 0.5796 - val_loss: 1.3285
# Epoch 3/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5013 - loss: 1.4682 - val_accuracy: 0.6346 - val_loss: 1.1913
# Epoch 4/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5392 - loss: 1.3341 - val_accuracy: 0.6658 - val_loss: 1.0740
# Epoch 5/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5828 - loss: 1.2331 - val_accuracy: 0.6948 - val_loss: 1.0036
# Epoch 6/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6139 - loss: 1.1466 - val_accuracy: 0.6917 - val_loss: 0.9937
# Epoch 7/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6301 - loss: 1.1042 - val_accuracy: 0.4070 - val_loss: 3.3891
# Epoch 8/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6433 - loss: 1.0547 - val_accuracy: 0.7198 - val_loss: 0.8977
# Epoch 9/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6642 - loss: 0.9994 - val_accuracy: 0.7322 - val_loss: 0.8586
# Epoch 10/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6748 - loss: 0.9560 - val_accuracy: 0.7391 - val_loss: 0.8207
# Epoch 11/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6878 - loss: 0.9268 - val_accuracy: 0.7515 - val_loss: 0.7902
# Epoch 12/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6996 - loss: 0.9033 - val_accuracy: 0.7686 - val_loss: 0.7460
# Epoch 13/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7096 - loss: 0.8712 - val_accuracy: 0.7622 - val_loss: 0.7598
# Epoch 14/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7267 - loss: 0.8283 - val_accuracy: 0.7671 - val_loss: 0.7292
# Epoch 15/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7329 - loss: 0.7986 - val_accuracy: 0.7845 - val_loss: 0.6977
# Epoch 16/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7427 - loss: 0.7790 - val_accuracy: 0.7870 - val_loss: 0.6806
# Epoch 17/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7484 - loss: 0.7547 - val_accuracy: 0.7882 - val_loss: 0.6736
# Epoch 18/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7452 - loss: 0.7536 - val_accuracy: 0.7833 - val_loss: 0.6918
# Epoch 19/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7647 - loss: 0.7170 - val_accuracy: 0.7878 - val_loss: 0.6680
# Epoch 20/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7646 - loss: 0.7098 - val_accuracy: 0.7884 - val_loss: 0.6606
# Epoch 21/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7652 - loss: 0.7045 - val_accuracy: 0.7961 - val_loss: 0.6388
# Epoch 22/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7778 - loss: 0.6648 - val_accuracy: 0.7837 - val_loss: 0.6699
# Epoch 23/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7763 - loss: 0.6730 - val_accuracy: 0.7945 - val_loss: 0.6336
# Epoch 24/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7781 - loss: 0.6508 - val_accuracy: 0.8117 - val_loss: 0.6122
# Epoch 25/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7834 - loss: 0.6379 - val_accuracy: 0.8003 - val_loss: 0.6271
# Epoch 26/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7886 - loss: 0.6309 - val_accuracy: 0.8072 - val_loss: 0.6219
# Epoch 27/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7970 - loss: 0.6047 - val_accuracy: 0.8044 - val_loss: 0.6188
# Epoch 28/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8016 - loss: 0.5984 - val_accuracy: 0.7963 - val_loss: 0.6413
# Epoch 29/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8059 - loss: 0.5952 - val_accuracy: 0.8006 - val_loss: 0.6300
# Epoch 30/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8055 - loss: 0.5900 - val_accuracy: 0.7921 - val_loss: 0.6573
# Epoch 31/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8096 - loss: 0.5818 - val_accuracy: 0.8026 - val_loss: 0.6258
# Epoch 32/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8094 - loss: 0.5753 - val_accuracy: 0.8062 - val_loss: 0.6322
# Epoch 33/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8120 - loss: 0.5612 - val_accuracy: 0.8023 - val_loss: 0.6135
# Epoch 34/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8116 - loss: 0.5568 - val_accuracy: 0.8157 - val_loss: 0.5745
# Epoch 35/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8236 - loss: 0.5339 - val_accuracy: 0.8102 - val_loss: 0.5815
# Epoch 36/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8198 - loss: 0.5369 - val_accuracy: 0.8144 - val_loss: 0.5976
# Epoch 37/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8219 - loss: 0.5320 - val_accuracy: 0.8175 - val_loss: 0.5837
# Epoch 38/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8238 - loss: 0.5368 - val_accuracy: 0.8226 - val_loss: 0.5734
# Epoch 39/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8255 - loss: 0.5160 - val_accuracy: 0.8120 - val_loss: 0.6047
# Epoch 40/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8233 - loss: 0.5323 - val_accuracy: 0.7999 - val_loss: 0.6338
# Epoch 41/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8265 - loss: 0.5273 - val_accuracy: 0.7999 - val_loss: 0.6300
# Epoch 42/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8342 - loss: 0.5057 - val_accuracy: 0.8081 - val_loss: 0.6042
# Epoch 43/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8321 - loss: 0.5119 - val_accuracy: 0.8104 - val_loss: 0.5958
# Epoch 44/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8303 - loss: 0.5056 - val_accuracy: 0.8199 - val_loss: 0.5689
# Epoch 45/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8305 - loss: 0.5081 - val_accuracy: 0.8063 - val_loss: 0.6076
# Epoch 46/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8373 - loss: 0.4945 - val_accuracy: 0.8078 - val_loss: 0.6177
# Epoch 47/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8343 - loss: 0.4868 - val_accuracy: 0.8089 - val_loss: 0.5945
# Epoch 48/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8436 - loss: 0.4656 - val_accuracy: 0.8198 - val_loss: 0.5673
# Epoch 49/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8486 - loss: 0.4478 - val_accuracy: 0.8081 - val_loss: 0.6104
# Epoch 50/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8441 - loss: 0.4651 - val_accuracy: 0.8282 - val_loss: 0.5734

# %%
# Plot validation accuracy for different optimizers
plt.figure(figsize=(12, 6))
for opt_name, history in histories.items():
    plt.plot(history.history['val_accuracy'], label=f'{opt_name}')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Optimizer Comparison on FCNN')
plt.show()

# %% [markdown]
# The RMSProp optimizer proved to be the best choice because it achieved the highest training accuracy, the best validation accuracy, and the lowest validation loss.
#
# Key takeaways so far:
# *   Normalization played a crucial role in improving optimization.
# *   Reducing the learning rate from 0.1 to 0.005 significantly helped.
# *   Before applying batch normalization, the accuracy for all optimizers was limited to a maximum of 50%.

# %%
from tensorflow.keras.callbacks import EarlyStopping
# choosing best optimizer
print("Training with ADAM: ")
best_model = build_fcnn(Adam(learning_rate=0.0005))
callbacks = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
best_model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_val, y_val), callbacks=callbacks, verbose=1)
# Out:
# Training with ADAM:
# Epoch 1/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.2967 - loss: 2.1230 - val_accuracy: 0.5028 - val_loss: 1.4490
# Epoch 2/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5527 - loss: 1.2928 - val_accuracy: 0.6652 - val_loss: 0.9813
# Epoch 3/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6360 - loss: 1.0670 - val_accuracy: 0.6906 - val_loss: 0.9202
# Epoch 4/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6806 - loss: 0.9377 - val_accuracy: 0.7123 - val_loss: 0.8439
# Epoch 5/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7121 - loss: 0.8573 - val_accuracy: 0.7304 - val_loss: 0.8082
# Epoch 6/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7386 - loss: 0.7621 - val_accuracy: 0.7973 - val_loss: 0.6213
# Epoch 7/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7577 - loss: 0.7202 - val_accuracy: 0.7738 - val_loss: 0.6847
# Epoch 8/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7742 - loss: 0.6686 - val_accuracy: 0.7729 - val_loss: 0.6713
# Epoch 9/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7777 - loss: 0.6540 - val_accuracy: 0.7931 - val_loss: 0.6110
# Epoch 10/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7799 - loss: 0.6432 - val_accuracy: 0.7894 - val_loss: 0.6083
# Epoch 11/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8062 - loss: 0.5704 - val_accuracy: 0.8072 - val_loss: 0.5734
# Epoch 12/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8081 - loss: 0.5667 - val_accuracy: 0.8002 - val_loss: 0.5997
# Epoch 13/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8205 - loss: 0.5337 - val_accuracy: 0.8027 - val_loss: 0.5902
# Epoch 14/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8202 - loss: 0.5176 - val_accuracy: 0.7695 - val_loss: 0.6935
# Epoch 15/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8287 - loss: 0.5031 - val_accuracy: 0.8268 - val_loss: 0.5246
# Epoch 16/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8424 - loss: 0.4582 - val_accuracy: 0.7849 - val_loss: 0.6492
# Epoch 17/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8448 - loss: 0.4523 - val_accuracy: 0.8374 - val_loss: 0.4731
# Epoch 18/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8560 - loss: 0.4197 - val_accuracy: 0.8400 - val_loss: 0.4856
# Epoch 19/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8569 - loss: 0.4177 - val_accuracy: 0.8256 - val_loss: 0.5303
# Epoch 20/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8548 - loss: 0.4303 - val_accuracy: 0.8063 - val_loss: 0.5848
# Epoch 21/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8656 - loss: 0.3876 - val_accuracy: 0.8279 - val_loss: 0.5257
# Epoch 22/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8752 - loss: 0.3710 - val_accuracy: 0.8252 - val_loss: 0.5554
# Epoch 23/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8665 - loss: 0.3880 - val_accuracy: 0.8243 - val_loss: 0.5414
# Epoch 24/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8773 - loss: 0.3640 - val_accuracy: 0.8372 - val_loss: 0.5067
# Epoch 25/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8762 - loss: 0.3620 - val_accuracy: 0.8261 - val_loss: 0.5409
# Epoch 26/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8830 - loss: 0.3465 - val_accuracy: 0.8309 - val_loss: 0.5337
# Epoch 27/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8891 - loss: 0.3294 - val_accuracy: 0.8309 - val_loss: 0.5204

# %%
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=1)
print(f"FCNN Test Accuracy: {test_accuracy:.4f} - Test Loss: {test_loss:.4f}")
# Out:
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8403 - loss: 0.4753
# FCNN Test Accuracy: 0.8389 - Test Loss: 0.4805

# %% [markdown]
# # CNN

# %%
X_train_cnn = X_train.reshape([-1, 129, 71, 1])
X_valid_cnn = X_val.reshape([-1, 129, 71, 1])
X_test_cnn = X_test.reshape([-1, 129, 71, 1])

print(f"x_train shape: {X_train_cnn.shape}")
print(f"x_valid shape: {X_valid_cnn.shape}")
print(f"x_test shape: {X_test_cnn.shape}")
# Out:
# x_train shape: (20042, 129, 71, 1)
# x_valid shape: (6681, 129, 71, 1)
# x_test shape: (8908, 129, 71, 1)

# %%
def build_cnn():
    model = Sequential([
        layers.Input(X_train_cnn[0].shape),
        layers.Conv2D(16, (3,3), activation = "swish", kernel_initializer = "he_normal"),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(32, (3,3), activation = "swish", kernel_initializer = "he_normal"),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3,3), activation = "swish", kernel_initializer = "he_normal"),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(64, activation = "swish", kernel_initializer = "he_normal"),
        layers.Dense(32, activation = "swish", kernel_initializer = "he_normal"),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.0005), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=3)

model = build_cnn()
history = model.fit(
    X_train_cnn, y_train,
    epochs=30,
    validation_data=(X_valid_cnn, y_val),
    callbacks=[early_stopping_cb, lr_scheduler]
)
# Out:
# Epoch 1/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1995 - loss: 3.0811 - val_accuracy: 0.5200 - val_loss: 1.4326 - learning_rate: 5.0000e-04
# Epoch 2/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5523 - loss: 1.3102 - val_accuracy: 0.7649 - val_loss: 0.7386 - learning_rate: 5.0000e-04
# Epoch 3/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7850 - loss: 0.6546 - val_accuracy: 0.8608 - val_loss: 0.4449 - learning_rate: 5.0000e-04
# Epoch 4/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8705 - loss: 0.3913 - val_accuracy: 0.8985 - val_loss: 0.3155 - learning_rate: 5.0000e-04
# Epoch 5/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9138 - loss: 0.2632 - val_accuracy: 0.9063 - val_loss: 0.2984 - learning_rate: 5.0000e-04
# Epoch 6/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9297 - loss: 0.2038 - val_accuracy: 0.9091 - val_loss: 0.2929 - learning_rate: 5.0000e-04
# Epoch 7/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9470 - loss: 0.1623 - val_accuracy: 0.9277 - val_loss: 0.2341 - learning_rate: 5.0000e-04
# Epoch 8/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9578 - loss: 0.1293 - val_accuracy: 0.9307 - val_loss: 0.2328 - learning_rate: 5.0000e-04
# Epoch 9/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9625 - loss: 0.1088 - val_accuracy: 0.9244 - val_loss: 0.2582 - learning_rate: 5.0000e-04
# Epoch 10/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9694 - loss: 0.0908 - val_accuracy: 0.9294 - val_loss: 0.2689 - learning_rate: 5.0000e-04
# Epoch 11/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9732 - loss: 0.0824 - val_accuracy: 0.9370 - val_loss: 0.2265 - learning_rate: 5.0000e-04
# Epoch 12/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9785 - loss: 0.0677 - val_accuracy: 0.9198 - val_loss: 0.3355 - learning_rate: 5.0000e-04
# Epoch 13/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9782 - loss: 0.0624 - val_accuracy: 0.9382 - val_loss: 0.2495 - learning_rate: 5.0000e-04
# Epoch 14/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9814 - loss: 0.0548 - val_accuracy: 0.9344 - val_loss: 0.2563 - learning_rate: 5.0000e-04
# Epoch 15/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9903 - loss: 0.0325 - val_accuracy: 0.9458 - val_loss: 0.2310 - learning_rate: 1.0000e-04
# Epoch 16/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9942 - loss: 0.0191 - val_accuracy: 0.9494 - val_loss: 0.2258 - learning_rate: 1.0000e-04
# Epoch 17/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9960 - loss: 0.0156 - val_accuracy: 0.9472 - val_loss: 0.2393 - learning_rate: 1.0000e-04
# Epoch 18/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9955 - loss: 0.0165 - val_accuracy: 0.9463 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 19/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 0.9482 - val_loss: 0.2473 - learning_rate: 1.0000e-04
# Epoch 20/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9969 - loss: 0.0114 - val_accuracy: 0.9502 - val_loss: 0.2420 - learning_rate: 2.0000e-05
# Epoch 21/30
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9977 - loss: 0.0090 - val_accuracy: 0.9493 - val_loss: 0.2407 - learning_rate: 2.0000e-05

# %% [markdown]
# **learning from CNN:**
#
# *   earlyStopping and ReduceLROnPlateau helped in fast learning
# *   Swish performed here too in comparison to other activation function
# *   Three convolutional layers provides an optimal balance too.

# %%
print(" CNN Loss + accuracy on test data: {}".format(model.evaluate(X_test_cnn, y_test)))
# Out:
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9405 - loss: 0.2717
#  CNN Loss + accuracy on test data: [0.2563173472881317, 0.9436461329460144]

# %% [markdown]
# CNN clearly performs better with accuracy of 95% on test data while FCNN with 83% of accuracy.

# %%
#plot training curves
import matplotlib.pyplot as plt

# Plot training & validation accuracy and loss
def plot_training_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))

    # Accuracy plot
    ax[0].plot(history.history['accuracy'], label='Train Accuracy')
    ax[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend()

    # Loss plot
    ax[1].plot(history.history['loss'], label='Train Loss')
    ax[1].plot(history.history['val_loss'], label='Validation Loss')
    ax[1].set_title('Model Loss')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Loss')
    ax[1].legend()

    plt.show()

plot_training_history(history)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Get predictions
y_pred = model.predict(X_test_cnn)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class indices

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# **Most Problematic Misclassifications:**
#
#   **Class 9 has the most notable misclassifications:**
# *   22 samples of class 9 were incorrectly classified as class 1
# *   20 samples of class 9 were incorrectly classified as class 5
#
#   **Class 3 shows some confusion:**
# *   23 samples of class 3 were misclassified as class 8
# *   16 samples of class 3 were misclassified as class 2
#
# **Other notable cross-class confusions:**
# *   Class 1 has 18 samples misclassified as class 4
# *   Class 5 has 14 samples misclassified as class 6
# *   Class 7 has 16 samples misclassified as class 8
#
# **Best Performing Classes:**
# *   Class 0 is the most accurately classified, with 878 correct predictions
# *   Class 2 and Class 7 also show high accuracy with 838 and 870 correct predictions respectively
#
# **Most Confused Pairs:**
#
#
# 1.   Class 9 and Class 1
# 2.   Class 3 and Class 8
# 3.   Class 5 and Class 6
# 4.   Class 1 and Class 4

# %%
import random

# Pick random samples from test set
num_samples = 10
indices = random.sample(range(len(X_test_cnn)), num_samples)
X_sample = X_test_cnn[indices]
y_sample_true = y_test[indices]

# Get model predictions
y_sample_pred = np.argmax(model.predict(X_sample), axis=1)

# Plot images with predictions
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.imshow(X_sample[i].reshape(129, 71), cmap='gray')  # Reshape for display
    ax.set_title(f"True: {y_sample_true[i]}\nPred: {y_sample_pred[i]}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step

# %%
# missclasssified example
# Get model predictions
y_pred = model.predict(X_test_cnn)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class indices

# Find misclassified indices
misclassified_indices = np.where(y_pred_classes != y_test)[0]

print(f"Total Misclassified Samples: {len(misclassified_indices)}")
# Out:
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Total Misclassified Samples: 502

# %%
import random

# Select random misclassified samples
num_samples = 10
random_indices = random.sample(list(misclassified_indices), min(num_samples, len(misclassified_indices)))

# Extract data
X_misclassified = X_test_cnn[random_indices]
y_true_misclassified = y_test[random_indices]
y_pred_misclassified = y_pred_classes[random_indices]

# Plot misclassified images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.imshow(X_misclassified[i].reshape(129, 71), cmap='gray')  # Reshape for display
    ax.set_title(f"True: {y_true_misclassified[i]}\nPred: {y_pred_misclassified[i]}")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# From the overall analysis, I got to conclusion that CNN performed better than FCNN and also there were only 502 misclassified samples overall.
